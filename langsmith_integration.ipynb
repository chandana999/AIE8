# %%
import os
import getpass
from langsmith import Client

# Enable LangSmith tracing
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("LangSmith API Key:")

# Create LangSmith client
client = Client()

print("✅ LangSmith client created successfully!")
# Out:
# ✅ LangSmith client created successfully!

# %%
# Out:
# ✅ Created new dataset: f859d190-688e-4ec3-9596-abb6ebab5b02
# Dataset ID: f859d190-688e-4ec3-9596-abb6ebab5b02
# Dataset Name: Web Log Analysis Dataset
